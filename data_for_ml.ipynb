# %% [markdown]
# ## Preparing Data for Machine Learning

# %% [markdown]
# ### Data Import and Loading

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Amazon Sale Report.csv")
# Out:
# C:\Users\thech\AppData\Local\Temp\ipykernel_6636\3820059884.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Amazon Sale Report.csv")

# %%
data
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0        Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1        Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2          Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3        Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4          Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
# ...           ...            ...                ...      ...              ...
# 128970     Amazon      Amazon.in          Expedited  JNE3697    JNE3697-KR-XL
# 128971     Amazon      Amazon.in          Expedited   SET401   SET401-KR-NP-M
# 128972     Amazon      Amazon.in          Expedited    J0157     J0157-DR-XXL
# 128973     Amazon      Amazon.in          Expedited    J0012     J0012-SKD-XS
# 128974     Amazon      Amazon.in          Expedited    J0003      J0003-SET-S
#
#              Category  ... currency   Amount    ship-city    ship-state  \
# 0                 Set  ...      INR   647.62       MUMBAI   MAHARASHTRA
# 1               kurta  ...      INR   406.00    BENGALURU     KARNATAKA
# 2               kurta  ...      INR   329.00  NAVI MUMBAI   MAHARASHTRA
# 3       Western Dress  ...      INR   753.33   PUDUCHERRY    PUDUCHERRY
# 4                 Top  ...      INR   574.00      CHENNAI    TAMIL NADU
# ...               ...  ...      ...      ...          ...           ...
# 128970          kurta  ...      INR   517.00    HYDERABAD     TELANGANA
# 128971            Set  ...      INR   999.00     GURUGRAM       HARYANA
# 128972  Western Dress  ...      INR   690.00    HYDERABAD     TELANGANA
# 128973            Set  ...      INR  1199.00        Halol       Gujarat
# 128974            Set  ...      INR   696.00       Raipur  CHHATTISGARH
#
#        ship-postal-code  ship-country  \
# 0              400081.0            IN
# 1              560085.0            IN
# 2              410210.0            IN
# 3              605008.0            IN
# 4              600073.0            IN
# ...                 ...           ...
# 128970         500013.0            IN
# 128971         122004.0            IN
# 128972         500049.0            IN
# 128973         389350.0            IN
# 128974         492014.0            IN
#
#                                             promotion-ids    B2B  \
# 0                                                     NaN  False
# 1       Amazon PLCC Free-Financing Universal Merchant ...  False
# 2            IN Core Free Shipping 2015/04/08 23-48-5-108   True
# 3                                                     NaN  False
# 4                                                     NaN  False
# ...                                                   ...    ...
# 128970                                                NaN  False
# 128971       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 128972                                                NaN  False
# 128973       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 128974       IN Core Free Shipping 2015/04/08 23-48-5-108  False
#
#         fulfilled-by Unnamed: 22
# 0          Easy Ship         NaN
# 1          Easy Ship         NaN
# 2                NaN         NaN
# 3          Easy Ship         NaN
# 4                NaN         NaN
# ...              ...         ...
# 128970           NaN       False
# 128971           NaN       False
# 128972           NaN       False
# 128973           NaN       False
# 128974           NaN       False
#
# [128975 rows x 24 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
#  15  Amount              121180 non-null  float64
#  16  ship-city           128942 non-null  object
#  17  ship-state          128942 non-null  object
#  18  ship-postal-code    128942 non-null  float64
#  19  ship-country        128942 non-null  object
#  20  promotion-ids       79822 non-null   object
#  21  B2B                 128975 non-null  bool
#  22  fulfilled-by        39277 non-null   object
#  23  Unnamed: 22         79925 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(19)
# memory usage: 22.8+ MB

# %% [markdown]
# ### - Data Profiling and Summary Statistics

# %%
data.head(3)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
#
#   Category  ... currency  Amount    ship-city   ship-state ship-postal-code  \
# 0      Set  ...      INR  647.62       MUMBAI  MAHARASHTRA         400081.0
# 1    kurta  ...      INR  406.00    BENGALURU    KARNATAKA         560085.0
# 2    kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA         410210.0
#
#    ship-country                                      promotion-ids    B2B  \
# 0            IN                                                NaN  False
# 1            IN  Amazon PLCC Free-Financing Universal Merchant ...  False
# 2            IN       IN Core Free Shipping 2015/04/08 23-48-5-108   True
#
#    fulfilled-by Unnamed: 22
# 0     Easy Ship         NaN
# 1     Easy Ship         NaN
# 2           NaN         NaN
#
# [3 rows x 24 columns]

# %%
data['fulfilled-by'].unique()
# Out:
# array(['Easy Ship', nan], dtype=object)

# %%
data['Courier Status'].unique()
# Out:
# array([nan, 'Shipped', 'Cancelled', 'Unshipped'], dtype=object)

# %%
data['Courier Status'].fillna("Not Completed", inplace=True)
# Out:
# C:\Users\thech\AppData\Local\Temp\ipykernel_6636\2808219036.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Courier Status'].fillna("Not Completed", inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      128975 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
#  15  Amount              121180 non-null  float64
#  16  ship-city           128942 non-null  object
#  17  ship-state          128942 non-null  object
#  18  ship-postal-code    128942 non-null  float64
#  19  ship-country        128942 non-null  object
#  20  promotion-ids       79822 non-null   object
#  21  B2B                 128975 non-null  bool
#  22  fulfilled-by        39277 non-null   object
#  23  Unnamed: 22         79925 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(19)
# memory usage: 22.8+ MB

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [index, Order ID, Date, Status, Fulfilment, Sales Channel , ship-service-level, Style, SKU, Category, Size, ASIN, Courier Status, Qty, currency, Amount, ship-city, ship-state, ship-postal-code, ship-country, promotion-ids, B2B, fulfilled-by, Unnamed: 22]
# Index: []
#
# [0 rows x 24 columns]

# %%
data['Order ID'].value_counts()
# Out:
# Order ID
# 171-5057375-2831560    12
# 403-4984515-8861958    12
# 404-9932919-6662730    11
# 403-0173977-3041148    11
# 408-3317403-1729937    10
#                        ..
# 403-8464685-9792368     1
# 407-2378184-3732358     1
# 403-0816822-3188305     1
# 402-8261465-0622733     1
# 408-7436540-8728312     1
# Name: count, Length: 120378, dtype: int64

# %%
data.loc[data['Order ID'] == '403-4984515-8861958', ['Order ID', 'SKU', 'Date', 'Fulfilment', 'Category', 'Status', 'Amount']]
# Out:
#                   Order ID                SKU      Date Fulfilment  \
# 31737  403-4984515-8861958    JNE3792-KR-XXXL  04-11-22     Amazon
# 31738  403-4984515-8861958    JNE3764-KR-XXXL  04-11-22     Amazon
# 31739  403-4984515-8861958    JNE3503-KR-XXXL  04-11-22     Amazon
# 31740  403-4984515-8861958      J0308-DR-XXXL  04-11-22     Amazon
# 31741  403-4984515-8861958    JNE3702-KR-XXXL  04-11-22     Amazon
# 31742  403-4984515-8861958    JNE3741-KR-XXXL  04-11-22     Amazon
# 31743  403-4984515-8861958    JNE3634-KR-XXXL  04-11-22     Amazon
# 31744  403-4984515-8861958  SET433-KR-NP-XXXL  04-11-22     Amazon
# 31745  403-4984515-8861958    JNE3636-KR-XXXL  04-11-22     Amazon
# 31746  403-4984515-8861958    JNE3633-KR-XXXL  04-11-22     Amazon
# 31747  403-4984515-8861958    JNE3813-KR-XXXL  04-11-22     Amazon
# 31748  403-4984515-8861958    JNE3638-KR-XXXL  04-11-22     Amazon
#
#             Category   Status  Amount
# 31737          kurta  Shipped   432.0
# 31738          kurta  Shipped   487.0
# 31739          kurta  Shipped   318.0
# 31740  Western Dress  Shipped   665.0
# 31741          kurta  Shipped   342.0
# 31742          kurta  Shipped   432.0
# 31743          kurta  Shipped   511.0
# 31744            Set  Shipped   666.0
# 31745          kurta  Shipped   459.0
# 31746          kurta  Shipped   459.0
# 31747          kurta  Shipped   635.0
# 31748          kurta  Shipped   517.0

# %%
unique_data = data['Unnamed: 22'].unique()

# %%
print(unique_data)
# Out:
# [nan False]

# %%
data['currency'].fillna("INR", inplace=True)
# Out:
# C:\Users\thech\AppData\Local\Temp\ipykernel_6636\1059774145.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['currency'].fillna("INR", inplace=True)

# %%
location_check = data[['ship-state', 'ship-city', 'ship-postal-code', 'ship-country']]

# %%
location_check[location_check['ship-state'].isnull()]
# Out:
#        ship-state ship-city  ship-postal-code ship-country
# 1871          NaN       NaN               NaN          NaN
# 1872          NaN       NaN               NaN          NaN
# 8752          NaN       NaN               NaN          NaN
# 11215         NaN       NaN               NaN          NaN
# 13252         NaN       NaN               NaN          NaN
# 15688         NaN       NaN               NaN          NaN
# 16787         NaN       NaN               NaN          NaN
# 18351         NaN       NaN               NaN          NaN
# 22930         NaN       NaN               NaN          NaN
# 24986         NaN       NaN               NaN          NaN
# 30379         NaN       NaN               NaN          NaN
# 37963         NaN       NaN               NaN          NaN
# 37964         NaN       NaN               NaN          NaN
# 60986         NaN       NaN               NaN          NaN
# 63040         NaN       NaN               NaN          NaN
# 73675         NaN       NaN               NaN          NaN
# 73746         NaN       NaN               NaN          NaN
# 73771         NaN       NaN               NaN          NaN
# 73772         NaN       NaN               NaN          NaN
# 73911         NaN       NaN               NaN          NaN
# 80011         NaN       NaN               NaN          NaN
# 80092         NaN       NaN               NaN          NaN
# 80455         NaN       NaN               NaN          NaN
# 84008         NaN       NaN               NaN          NaN
# 84757         NaN       NaN               NaN          NaN
# 104201        NaN       NaN               NaN          NaN
# 106498        NaN       NaN               NaN          NaN
# 124215        NaN       NaN               NaN          NaN
# 124357        NaN       NaN               NaN          NaN
# 124358        NaN       NaN               NaN          NaN
# 124359        NaN       NaN               NaN          NaN
# 125385        NaN       NaN               NaN          NaN
# 126620        NaN       NaN               NaN          NaN

# %%
data['fulfilled-by'].value_counts()
# Out:
# fulfilled-by
# Easy Ship    39277
# Name: count, dtype: int64

# %%
data.drop(['fulfilled-by'], axis=1, inplace=True)

# %%
data['ship-country'].unique()
# Out:
# array(['IN', nan], dtype=object)

# %%
data['Unnamed: 22'].unique()
# Out:
# array([nan, False], dtype=object)

# %%
data.fillna({'Unnamed: 22': 'unknown'}, inplace=True)

# %%
data.drop(['promotion-ids'], axis=1, inplace=True)

# %%
data.dropna(subset=['ship-state', 'ship-city', 'ship-postal-code', 'ship-country'], inplace=True)

# %%
data.drop(['ship-country'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128942 entries, 0 to 128974
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128942 non-null  int64
#  1   Order ID            128942 non-null  object
#  2   Date                128942 non-null  object
#  3   Status              128942 non-null  object
#  4   Fulfilment          128942 non-null  object
#  5   Sales Channel       128942 non-null  object
#  6   ship-service-level  128942 non-null  object
#  7   Style               128942 non-null  object
#  8   SKU                 128942 non-null  object
#  9   Category            128942 non-null  object
#  10  Size                128942 non-null  object
#  11  ASIN                128942 non-null  object
#  12  Courier Status      128942 non-null  object
#  13  Qty                 128942 non-null  int64
#  14  currency            128942 non-null  object
#  15  Amount              128898 non-null  float64
#  16  ship-city           128942 non-null  object
#  17  ship-state          128942 non-null  object
#  18  ship-postal-code    128942 non-null  float64
#  19  B2B                 128942 non-null  bool
#  20  Unnamed: 22         128942 non-null  object
# dtypes: bool(1), float64(2), int64(2), object(16)
# memory usage: 20.8+ MB

# %%
location_check['ship-city'].value_counts()
# Out:
# ship-city
# BENGALURU              11217
# HYDERABAD               8074
# MUMBAI                  6126
# NEW DELHI               5795
# CHENNAI                 5421
#                        ...
# shimoga                    1
# Bangluru                   1
# Dombiwali                  1
# Begumpet, Hyderabad        1
# Badlapur , Thane           1
# Name: count, Length: 8955, dtype: int64

# %%
location_check[location_check['ship-city'] == 'BENGALURU']
# Out:
#        ship-state  ship-city  ship-postal-code ship-country
# 1       KARNATAKA  BENGALURU          560085.0           IN
# 19      KARNATAKA  BENGALURU          560017.0           IN
# 21      KARNATAKA  BENGALURU          560040.0           IN
# 28      KARNATAKA  BENGALURU          560037.0           IN
# 53      KARNATAKA  BENGALURU          560047.0           IN
# ...           ...        ...               ...          ...
# 128852  KARNATAKA  BENGALURU          560024.0           IN
# 128912  KARNATAKA  BENGALURU          560037.0           IN
# 128939  KARNATAKA  BENGALURU          560035.0           IN
# 128941  KARNATAKA  BENGALURU          560102.0           IN
# 128942  KARNATAKA  BENGALURU          560102.0           IN
#
# [11217 rows x 4 columns]

# %%
location_check
# Out:
#           ship-state    ship-city  ship-postal-code ship-country
# 0        MAHARASHTRA       MUMBAI          400081.0           IN
# 1          KARNATAKA    BENGALURU          560085.0           IN
# 2        MAHARASHTRA  NAVI MUMBAI          410210.0           IN
# 3         PUDUCHERRY   PUDUCHERRY          605008.0           IN
# 4         TAMIL NADU      CHENNAI          600073.0           IN
# ...              ...          ...               ...          ...
# 128970     TELANGANA    HYDERABAD          500013.0           IN
# 128971       HARYANA     GURUGRAM          122004.0           IN
# 128972     TELANGANA    HYDERABAD          500049.0           IN
# 128973       Gujarat        Halol          389350.0           IN
# 128974  CHHATTISGARH       Raipur          492014.0           IN
#
# [128975 rows x 4 columns]

# %%
data[data['Amount'].isna()][['Amount', 'Qty', 'SKU', 'Status', 'ship-city']].head(120)
# Out:
#         Amount  Qty                   SKU     Status  \
# 363        NaN    0        SET226-KR-PP-L  Cancelled
# 3632       NaN    1      JNE2058-KR-339-L    Shipped
# 3634       NaN    1       JNE3311-KR-A-XS    Shipped
# 3637       NaN    2           BL020-71RED    Shipped
# 3971       NaN    0          J0250-SKD-XS  Cancelled
# 6744       NaN    0          BTM002-B-XXL  Cancelled
# 6793       NaN    0          BTM002-B-XXL  Cancelled
# 6802       NaN    0          BTM002-B-XXL  Cancelled
# 6832       NaN    0          BTM002-B-XXL  Cancelled
# 7057       NaN    0           J0155-KR-XS  Cancelled
# 7084       NaN    0         J0024-KR-XXXL  Cancelled
# 10844      NaN    0         JNE3557-KR-XL  Cancelled
# 13732      NaN    1           BTM030-NP-S    Shipped
# 16157      NaN    0          J0184-KR-A-L  Cancelled
# 16162      NaN    0          J0184-KR-A-L  Cancelled
# 18676      NaN    1       JNE3225-KR-XXXL    Shipped
# 20813      NaN    2            J0184-KR-S    Shipped
# 28434      NaN    0        SET226-KR-PP-L  Cancelled
# 30603      NaN    0      SET043-KR-NP-XXL  Cancelled
# 34692      NaN    0           J0086-DR-XL  Cancelled
# 43746      NaN    1        JNE3441-KR-E-M    Shipped
# 59207      NaN    0             BL100-XXL  Cancelled
# 59208      NaN    0             BL100-XXL  Cancelled
# 63785      NaN    0         JNE3447-KR-XL  Cancelled
# 64307      NaN    0         JNE3780-KR-XS  Cancelled
# 64504      NaN    0          JNE3662-TP-M  Cancelled
# 64633      NaN    0              BL091-XL  Cancelled
# 81587      NaN    0       JNE2294-KR-A-XS  Cancelled
# 84876      NaN    1  JNE3366-KR-1053-A-XS    Shipped
# 84879      NaN    1      JNE2251-KR-537-S    Shipped
# 84881      NaN    1            J0100-DR-S    Shipped
# 85414      NaN    0        SET083-KR-PP-L  Cancelled
# 90521      NaN    0    JNE3364-KR-1051-XS  Cancelled
# 91852      NaN    0          JNE3909-KR-L  Cancelled
# 92943      NaN    0            J0374-KR-M  Cancelled
# 94169      NaN    0                SAR060  Cancelled
# 94676      NaN    0        JNE3891-TP-XXL  Cancelled
# 99019      NaN    0            J0073-KR-S  Cancelled
# 100683     NaN    0          JNE3897-KR-M  Cancelled
# 102001     NaN    0                SAR182  Cancelled
# 102461     NaN    0          JNE3483-KR-M  Cancelled
# 102546     NaN    0        JNE3403-KR-XXL  Cancelled
# 107194     NaN    0        JNE2145-KR-A-L  Cancelled
# 124675     NaN    0           J0034-SET-S  Cancelled
#
#                                   ship-city
# 363                               BAGESHWAR
# 3632                                  Surat
# 3634                                  Surat
# 3637                                  Surat
# 3971                                 KARNAL
# 6744                              BENGALURU
# 6793                              BENGALURU
# 6802                              BENGALURU
# 6832                              BENGALURU
# 7057                             SAMASTIPUR
# 7084                                 MUMBAI
# 10844                            COIMBATORE
# 13732                                 Surat
# 16157   BASUDEBPUR PURBA MEDINIPUR DISTRICT
# 16162   BASUDEBPUR PURBA MEDINIPUR DISTRICT
# 18676                                 Surat
# 20813                                 SURAT
# 28434                            Naharlagun
# 30603                           CHINNAMANUR
# 34692                                GODHRA
# 43746                                 SURAT
# 59207                             HYDERABAD
# 59208                             HYDERABAD
# 63785                                NAGPUR
# 64307                      PIMPRI CHINCHWAD
# 64504                               SILCHAR
# 64633                             AHMEDABAD
# 81587                                  KOTA
# 84876                                 Surat
# 84879                                 Surat
# 84881                                 Surat
# 85414                             NEW DELHI
# 90521                        RAMANATHAPURAM
# 91852                            BHIMAVARAM
# 92943                              AZAMGARH
# 94169                              TIRUPATI
# 94676                                 SURAT
# 99019                                MYSURU
# 100683                               KALYAN
# 102001                         NAGARKURNOOL
# 102461                               KALYAN
# 102546                               JAIPUR
# 107194                   THIRUVANANTHAPURAM
# 124675                            Bhagalpur

# %%
mean_amount_per_sku = data.groupby('SKU')['Amount'].transform('mean')

# %%
mean_amount_per_sku
# Out:
# 0          633.765714
# 1          416.050495
# 2          332.553077
# 3          806.907556
# 4          626.720000
#              ...
# 128970     468.396806
# 128971    1032.800000
# 128972     736.793478
# 128973    1124.000000
# 128974     652.285000
# Name: Amount, Length: 128942, dtype: float64

# %%
data['Amount'] = data['Amount'].fillna(mean_amount_per_sku)

# %%
sku_missing = data.groupby('SKU')['Amount'].apply(lambda x: x.isna().all())
print(sku_missing[sku_missing])
# Out:
# Series([], Name: Amount, dtype: bool)

# %%
data.loc[data['Amount'].isna(), ['Amount', 'SKU']]
# Out:
# Empty DataFrame
# Columns: [Amount, SKU]
# Index: []

# %%
data = data.dropna(subset=['Amount'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 128898 entries, 0 to 128974
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128898 non-null  int64
#  1   Order ID            128898 non-null  object
#  2   Date                128898 non-null  object
#  3   Status              128898 non-null  object
#  4   Fulfilment          128898 non-null  object
#  5   Sales Channel       128898 non-null  object
#  6   ship-service-level  128898 non-null  object
#  7   Style               128898 non-null  object
#  8   SKU                 128898 non-null  object
#  9   Category            128898 non-null  object
#  10  Size                128898 non-null  object
#  11  ASIN                128898 non-null  object
#  12  Courier Status      128898 non-null  object
#  13  Qty                 128898 non-null  int64
#  14  currency            128898 non-null  object
#  15  Amount              128898 non-null  float64
#  16  ship-city           128898 non-null  object
#  17  ship-state          128898 non-null  object
#  18  ship-postal-code    128898 non-null  float64
#  19  B2B                 128898 non-null  bool
#  20  Unnamed: 22         128898 non-null  object
# dtypes: bool(1), float64(2), int64(2), object(16)
# memory usage: 20.8+ MB

# %% [markdown]
# ## Implement Linear Regression Without Using Libraries
